# %%
# %reload_kedro
# Out:
# [02/04/25 21:19:39] INFO     Resolved project path as: /Users/sharkovgrigory/code/fraud_detection.  ]8;id=894178;file:///Users/sharkovgrigory/miniconda3/envs/gnn_test/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=991903;file:///Users/sharkovgrigory/miniconda3/envs/gnn_test/lib/python3.12/site-packages/kedro/ipython/__init__.py#178\178]8;;\
#                              To set a different path, run '%reload_kedro <project_root>'
#                     INFO     Kedro project fraud_detection                                          ]8;id=183814;file:///Users/sharkovgrigory/miniconda3/envs/gnn_test/lib/python3.12/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=369280;file:///Users/sharkovgrigory/miniconda3/envs/gnn_test/lib/python3.12/site-packages/kedro/ipython/__init__.py#144\144]8;;\
# ...

# %%
raw_features = catalog.load("raw_features")
# Out:
# [02/04/25 21:17:59] INFO     Loading data from raw_features (CSVDataset)...                     ]8;id=423048;file:///Users/sharkovgrigory/miniconda3/envs/gnn_test/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=597422;file:///Users/sharkovgrigory/miniconda3/envs/gnn_test/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
raw_features
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               0    1         2         3         4          5         6    \
# 0       230425980    1 -0.171469 -0.184668 -1.201369  -0.121970 -0.043875
# 1         5530458    1 -0.171484 -0.184668 -1.201369  -0.121970 -0.043875
# 2       232022460    1 -0.172107 -0.184668 -1.201369  -0.121970 -0.043875
# 3       232438397    1  0.163054  1.963790 -0.646376  12.409294 -0.063725
# 4       230460314    1  1.011523 -0.081127 -1.201369   1.153668  0.333276
# ...           ...  ...       ...       ...       ...        ...       ...
# 203764  173077460   49 -0.145771 -0.163752  0.463609  -0.121970 -0.043875
# 203765  158577750   49 -0.165920 -0.123607  1.018602  -0.121970 -0.043875
# 203766  158375402   49 -0.172014 -0.078182  1.018602   0.028105 -0.043875
# 203767  158654197   49 -0.172842 -0.176622  1.018602  -0.121970 -0.043875
# ...

# %%
processed_data = catalog.load("processed_data")
# Out:
# [02/04/25 21:20:22] INFO     Loading data from processed_data (PickleDataset)...                ]8;id=923631;file:///Users/sharkovgrigory/miniconda3/envs/gnn_test/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=437887;file:///Users/sharkovgrigory/miniconda3/envs/gnn_test/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\

# %%
processed_data
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Data(x=[203769, 166], edge_index=[2, 234355], y=[203769], train_mask=[203769], val_mask=[203769], test_mask=[203769], known_mask=[203769])
